# %%
import requests
import time
import pandas as pd

# %%
# API endpoint
url_detail = "https://pokeapi.co/api/v2/pokemon/"
# Create empty list
pokemon_detail = []

for i in range(40):
    new_url_detail = url_detail + str(i+1)
    # Get request and transform to Json
    response = requests.get(new_url_detail).json()
    
    data_detail = [
            response['id'],
            response['name'],
            response['height'],
            response['weight'],
            response['types']
    ]
    
    pokemon_detail.append(data_detail)  # append data in empty list
    time.sleep(2)
    
#print(pokemon_detail)

# %%
url_species = "https://pokeapi.co/api/v2/pokemon-species/"
# Create empty list
pokemon_species = []

for i in range(40):
    new_url_species = url_species + str(i+1)
    # Get request and transform to Json
    response = requests.get(new_url_species).json()
    
    data_species = [
            response["name"],
            response["capture_rate"],
            response["color"],
            response["habitat"]
    ]
    
    pokemon_species.append(data_species)
    time.sleep(2)
    
#print(pokemon_species)

# %% [markdown]
# # Create DataFrame

# %%
df_detail = pd.DataFrame(pokemon_detail, columns = ["id", "name", "height", "weight", "types"])

df_detail.head()
# Out:
#    id        name  height  weight  \
# 0   1   bulbasaur       7      69
# 1   2     ivysaur      10     130
# 2   3    venusaur      20    1000
# 3   4  charmander       6      85
# 4   5  charmeleon      11     190
#
#                                                types
# 0  [{'slot': 1, 'type': {'name': 'grass', 'url': ...
# 1  [{'slot': 1, 'type': {'name': 'grass', 'url': ...
# 2  [{'slot': 1, 'type': {'name': 'grass', 'url': ...
# 3  [{'slot': 1, 'type': {'name': 'fire', 'url': '...
# 4  [{'slot': 1, 'type': {'name': 'fire', 'url': '...

# %%
df_species = pd.DataFrame(pokemon_species, columns = ["name", "capture_rate", "color", "habitat"])

df_species.head()
# Out:
#          name  capture_rate  \
# 0   bulbasaur            45
# 1     ivysaur            45
# 2    venusaur            45
# 3  charmander            45
# 4  charmeleon            45
#
#                                                color  \
# 0  {'name': 'green', 'url': 'https://pokeapi.co/a...
# 1  {'name': 'green', 'url': 'https://pokeapi.co/a...
# 2  {'name': 'green', 'url': 'https://pokeapi.co/a...
# 3  {'name': 'red', 'url': 'https://pokeapi.co/api...
# 4  {'name': 'red', 'url': 'https://pokeapi.co/api...
#
#                                              habitat
# 0  {'name': 'grassland', 'url': 'https://pokeapi....
# 1  {'name': 'grassland', 'url': 'https://pokeapi....
# 2  {'name': 'grassland', 'url': 'https://pokeapi....
# 3  {'name': 'mountain', 'url': 'https://pokeapi.c...
# 4  {'name': 'mountain', 'url': 'https://pokeapi.c...

# %% [markdown]
# # Data Cleansing

# %% [markdown]
# #### Clean and Extract Pokemon Type where the format in the 'types' colmn is something like [{'slot': 1, 'type': {'name': 'grass', 'url': ...], which is dictionary with outer key-value pair.  e.g., filter only 'grass'

# %%
# Extract values associated with the key 'name' in the 'types' column
df_detail['types'] = df_detail['types'].apply(lambda x: [item['type']['name'] for item in x])

df_detail.head()
# Out:
#    id        name  height  weight            types
# 0   1   bulbasaur       7      69  [grass, poison]
# 1   2     ivysaur      10     130  [grass, poison]
# 2   3    venusaur      20    1000  [grass, poison]
# 3   4  charmander       6      85           [fire]
# 4   5  charmeleon      11     190           [fire]

# %% [markdown]
# #### Clean and Extract Pokemon 'color' and 'habitat' as above process. In this case, the structure is a simple dictionary without additional nesting

# %%
# Extract words between 'name': ' and ',
df_species['color'] = df_species['color'].astype(str).str.extract(r"'name': '(.*?)',")
df_species['habitat'] = df_species['habitat'].astype(str).str.extract(r"'name': '(.*?)',")

df_species.head()
# Out:
#          name  capture_rate  color    habitat
# 0   bulbasaur            45  green  grassland
# 1     ivysaur            45  green  grassland
# 2    venusaur            45  green  grassland
# 3  charmander            45    red   mountain
# 4  charmeleon            45    red   mountain

# %% [markdown]
# # Join DataFrame

# %%
full_pokemon = pd.merge(df_detail, df_species, how="inner", on ="name")
full_pokemon.head()
# Out:
#    id        name  height  weight            types  capture_rate  color  \
# 0   1   bulbasaur       7      69  [grass, poison]            45  green
# 1   2     ivysaur      10     130  [grass, poison]            45  green
# 2   3    venusaur      20    1000  [grass, poison]            45  green
# 3   4  charmander       6      85           [fire]            45    red
# 4   5  charmeleon      11     190           [fire]            45    red
#
#      habitat
# 0  grassland
# 1  grassland
# 2  grassland
# 3   mountain
# 4   mountain

# %%
full_pokemon.tail()
# Out:
#     id        name  height  weight            types  capture_rate   color  \
# 35  36    clefable      13     400          [fairy]            25    pink
# 36  37      vulpix       6      99           [fire]           190   brown
# 37  38   ninetales      11     199           [fire]            75  yellow
# 38  39  jigglypuff       5      55  [normal, fairy]           170    pink
# 39  40  wigglytuff      10     120  [normal, fairy]            50    pink
#
#       habitat
# 35   mountain
# 36  grassland
# 37  grassland
# 38  grassland
# 39  grassland

# %% [markdown]
# # Finding Insights

# %% [markdown]
# #### Find the number of pokemon separated by habitat

# %%
count_by_habitat = full_pokemon.groupby('habitat')['name'].count().reset_index(name='number of pokemon')
count_by_habitat
# Out:
#          habitat  number of pokemon
# 0         forest                 11
# 1      grassland                 17
# 2       mountain                  5
# 3  rough-terrain                  4
# 4    waters-edge                  3

# %% [markdown]
# #### Find the number of pokemon separated by color

# %%
color = full_pokemon.groupby('color')['name'].agg(['count', 'unique']).reset_index()
color.columns = ['color', 'number of pokemon', 'pokemon list']

# %%
color
# Out:
#     color  number of pokemon  \
# 0    blue                  6
# 1   brown                  8
# 2   green                  5
# 3    pink                  4
# 4  purple                  6
# 5     red                  3
# 6   white                  1
# 7  yellow                  7
#
#                                         pokemon list
# 0  [squirtle, wartortle, blastoise, nidoran-f, ni...
# 1  [weedle, pidgey, pidgeotto, pidgeot, raticate,...
# 2  [bulbasaur, ivysaur, venusaur, caterpie, metapod]
# 3       [clefairy, clefable, jigglypuff, wigglytuff]
# 4  [rattata, ekans, arbok, nidoran-m, nidorino, n...
# 5                [charmander, charmeleon, charizard]
# 6                                       [butterfree]
# 7  [kakuna, beedrill, pikachu, raichu, sandshrew,...

# %%
full_pokemon
# Out:
#     id        name  height  weight             types  capture_rate   color  \
# 0    1   bulbasaur       7      69   [grass, poison]            45   green
# 1    2     ivysaur      10     130   [grass, poison]            45   green
# 2    3    venusaur      20    1000   [grass, poison]            45   green
# 3    4  charmander       6      85            [fire]            45     red
# 4    5  charmeleon      11     190            [fire]            45     red
# 5    6   charizard      17     905    [fire, flying]            45     red
# 6    7    squirtle       5      90           [water]            45    blue
# 7    8   wartortle      10     225           [water]            45    blue
# 8    9   blastoise      16     855           [water]            45    blue
# 9   10    caterpie       3      29             [bug]           255   green
# 10  11     metapod       7      99             [bug]           120   green
# 11  12  butterfree      11     320     [bug, flying]            45   white
# 12  13      weedle       3      32     [bug, poison]           255   brown
# 13  14      kakuna       6     100     [bug, poison]           120  yellow
# 14  15    beedrill      10     295     [bug, poison]            45  yellow
# 15  16      pidgey       3      18  [normal, flying]           255   brown
# 16  17   pidgeotto      11     300  [normal, flying]           120   brown
# 17  18     pidgeot      15     395  [normal, flying]            45   brown
# 18  19     rattata       3      35          [normal]           255  purple
# 19  20    raticate       7     185          [normal]           127   brown
# 20  21     spearow       3      20  [normal, flying]           255   brown
# 21  22      fearow      12     380  [normal, flying]            90   brown
# 22  23       ekans      20      69          [poison]           255  purple
# 23  24       arbok      35     650          [poison]            90  purple
# 24  25     pikachu       4      60        [electric]           190  yellow
# 25  26      raichu       8     300        [electric]            75  yellow
# 26  27   sandshrew       6     120          [ground]           255  yellow
# 27  28   sandslash      10     295          [ground]            90  yellow
# 28  29   nidoran-f       4      70          [poison]           235    blue
# 29  30    nidorina       8     200          [poison]           120    blue
# 30  31   nidoqueen      13     600  [poison, ground]            45    blue
# 31  32   nidoran-m       5      90          [poison]           235  purple
# 32  33    nidorino       9     195          [poison]           120  purple
# 33  34    nidoking      14     620  [poison, ground]            45  purple
# 34  35    clefairy       6      75           [fairy]           150    pink
# 35  36    clefable      13     400           [fairy]            25    pink
# 36  37      vulpix       6      99            [fire]           190   brown
# 37  38   ninetales      11     199            [fire]            75  yellow
# 38  39  jigglypuff       5      55   [normal, fairy]           170    pink
# 39  40  wigglytuff      10     120   [normal, fairy]            50    pink
#
#           habitat
# 0       grassland
# 1       grassland
# 2       grassland
# 3        mountain
# 4        mountain
# 5        mountain
# 6     waters-edge
# 7     waters-edge
# 8     waters-edge
# 9          forest
# 10         forest
# 11         forest
# 12         forest
# 13         forest
# 14         forest
# 15         forest
# 16         forest
# 17         forest
# 18      grassland
# 19      grassland
# 20  rough-terrain
# 21  rough-terrain
# 22      grassland
# 23      grassland
# 24         forest
# 25         forest
# 26  rough-terrain
# 27  rough-terrain
# 28      grassland
# 29      grassland
# 30      grassland
# 31      grassland
# 32      grassland
# 33      grassland
# 34       mountain
# 35       mountain
# 36      grassland
# 37      grassland
# 38      grassland
# 39      grassland

# %% [markdown]
# #### Find Basic Stats
# - weight of Pokemon (hectograms)
# - height of Pokemon (decimetres)

# %%
full_pokemon[['height', 'weight']].describe().round(2)
# Out:
#        height   weight
# count   40.00    40.00
# mean     9.57   249.35
# std      6.16   253.92
# min      3.00    18.00
# 25%      5.75    73.75
# 50%      8.50   157.50
# 75%     11.25   305.00
# max     35.00  1000.00

# %% [markdown]
# #### Dealing with capture_rate column
# The base capture rate ranges from 1 to 255, with higher values indicating an increased likelihood of successful capture.

# %%
# Create an empty list to store the catch levels
catch_level = []

# Iterate over the values in the "capture_rate" column
for rate in full_pokemon['capture_rate']:
    try:
        rate = float(rate)
        if rate <= 85:
            catch_level.append('hard')
        elif 85 < rate <= 170:
            catch_level.append('normal')
        elif 170 < rate <= 255:
            catch_level.append('easy')
    except ValueError:
        catch_level.append('unknown')

# Assign the catch_level list as a new column in the DataFrame
full_pokemon['catch_level'] = catch_level

# Print the resulting DataFrame as a table
full_pokemon.head()
# Out:
#    id        name  height  weight            types  capture_rate  color  \
# 0   1   bulbasaur       7      69  [grass, poison]            45  green
# 1   2     ivysaur      10     130  [grass, poison]            45  green
# 2   3    venusaur      20    1000  [grass, poison]            45  green
# 3   4  charmander       6      85           [fire]            45    red
# 4   5  charmeleon      11     190           [fire]            45    red
#
#      habitat catch_level
# 0  grassland        hard
# 1  grassland        hard
# 2  grassland        hard
# 3   mountain        hard
# 4   mountain        hard

# %% [markdown]
# #### Find the number of pokemon separated by catch_level

# %%
catchlevel = full_pokemon.groupby('catch_level')['name'].agg(['count', 'unique']).reset_index()
catchlevel.columns = ['catch_level', 'number of pokemon', 'pokemon list']

# %%
catchlevel
# Out:
#   catch_level  number of pokemon  \
# 0        easy                 11
# 1        hard                 18
# 2      normal                 11
#
#                                         pokemon list
# 0  [caterpie, weedle, pidgey, rattata, spearow, e...
# 1  [bulbasaur, ivysaur, venusaur, charmander, cha...
# 2  [metapod, kakuna, pidgeotto, raticate, fearow,...

# %% [markdown]
# ## Save File

# %%
#full_pokemon.to_csv("Pokemon.csv", index=False)
